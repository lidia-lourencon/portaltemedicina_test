# %%
import pandas as pd
import numpy as np

data = pd.read_csv("test_data_lidia_4.csv", delimiter=";")

# test_data_lidia_4.corr()
data.corr()
# Out:
#               index       age       sex  cp  trestbps      chol       fbs  \
# index      1.000000  0.030224  0.103547 NaN  0.089938  0.001521  0.059404
# age        0.030224  1.000000 -0.095453 NaN  0.284418  0.227584  0.123899
# sex        0.103547 -0.095453  1.000000 NaN -0.057594 -0.232084  0.029891
# cp              NaN       NaN       NaN NaN       NaN       NaN       NaN
# trestbps   0.089938  0.284418 -0.057594 NaN  1.000000  0.105901  0.193263
# chol       0.001521  0.227584 -0.232084 NaN  0.105901  1.000000  0.025515
# fbs        0.059404  0.123899  0.029891 NaN  0.193263  0.025515  1.000000
# restecg   -0.140705 -0.119609 -0.044233 NaN -0.100753 -0.139443 -0.061941
# thalach    0.007503 -0.414447 -0.034308 NaN -0.081598 -0.004534  0.004902
# exang      0.089962  0.097387  0.127497 NaN  0.084592  0.046309  0.006120
# oldpeak   -0.025468  0.207286  0.106737 NaN  0.223608  0.042392  0.015351
# slope     -0.017234 -0.222163  0.017070 NaN -0.101891 -0.040443 -0.083786
# ...
